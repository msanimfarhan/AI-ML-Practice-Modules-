# %% [markdown]
# # Multi Variate Analysis

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('titanic_data_updated.csv') 
df.drop_duplicates()
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       no   third
# 1              2      yes   first
# 2              3      yes   third
# 3              4      yes   first
# 4              5       no   third
# ..           ...      ...     ...
# 886          887       no  second
# 887          888      yes   first
# 888          889       no   third
# 889          890      yes   first
# 890          891       no   third
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
sns.countplot(x=df['Sex'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
gender_split = df.groupby('Sex')['Survived'].value_counts(normalize=True) 
print(gender_split)
# Out:
# Sex     Survived
# female  yes         0.742038
#         no          0.257962
# male    no          0.811092
#         yes         0.188908
# Name: proportion, dtype: float64

# %%
sns.countplot(x=df['Pclass'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pclass_split=df.groupby('Pclass')['Survived'].value_counts(normalize=True) 
print(pclass_split)
# Out:
# Pclass  Survived
# first   yes         0.629630
#         no          0.370370
# second  no          0.527174
#         yes         0.472826
# third   no          0.757637
#         yes         0.242363
# Name: proportion, dtype: float64

# %% [markdown]
# # Stratify

# %%
sns.barplot(x=df['Pclass'],y=df['Fare'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# # black mark above is confidence interval

# %%
sns.barplot(x=df['Survived'],y=df['Age'],hue=df['Sex'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# # Density Graph it is basically KDE plot

# %%
sns.kdeplot(data=df,x='Age',hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Multivariate Analysis using ScatterPlot

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=df,x='total_bill'
                ,y='tip',
                hue='sex',
                size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Y Data Profiling automates the EDA

# %%
pip install ydata_profiling
# Out:
# Requirement already satisfied: ydata_profiling in c:\users\sanim\anaconda3\lib\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (2.13.2)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\sanim\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (2.1.3)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\sanim\anaconda3\lib\site-packages (from ydata_profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\users\sanim\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata_profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\sanim\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata_profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sanim\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata_profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sanim\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sanim\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sanim\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sanim\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\sanim\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sanim\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sanim\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\sanim\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata_profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sanim\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sanim\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\sanim\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata_profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sanim\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\users\sanim\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (2.46.2)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\sanim\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sanim\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata_profiling) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sanim\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanim\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanim\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanim\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (2026.4.22)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\sanim\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\sanim\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata_profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\sanim\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\sanim\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.4.2)
# Requirement already satisfied: puremagic in c:\users\sanim\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\sanim\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport

# %%
profile= ProfileReport(df,title='Titanic Profile Report')
profile.to_file('my_report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 7/7 [00:00<00:00, 437.58it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
