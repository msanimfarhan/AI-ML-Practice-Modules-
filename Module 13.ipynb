# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# %% [markdown]
# 2D Line Plot

# %%
hours = [2,3,4,1,5,7,3] 
days = [1,2,3,4,5,6,7] 

plt.plot(days,hours)

# %%
plt.xlabel('Days')
plt.ylabel('Hours Studied')
plt.title('Weekly study trend')
plt.plot(days,hours)

# %%
hours_1 = [2,3,4,1,5,7,3] 
hours_2 = [1,4,3,5,5,2,1] 
days = [1,2,3,4,5,6,7] 
plt.xlabel('Days')
plt.ylabel('Hours Studied')
plt.title('Weekly study trend')
plt.plot(days,hours_1)
plt.plot(days,hours_2)

# %% [markdown]
# # 2D Line from Pandas DF

# %%
df = pd.read_csv('enrollment_data.csv')
df
# Out:
#    Year  Programming  Digital Marketing
# 0  2015          589                734
# 1  2016          862                963
# 2  2017         1085               1157
# 3  2018         1150               1404
# 4  2019         1439               1497
# 5  2020         1715               1579
# 6  2021         1785               1948
# 7  2022         1995               2073
# 8  2023         2236               2310
# 9  2024         2442               2338

# %%
plt.xlabel('Years')
plt.ylabel('Count of enrollment')
plt.title('Student Enrollment over 8 Years')
plt.plot(df['Year'],df['Programming'],label='Programming')
plt.plot(df['Year'],df['Digital Marketing'],label='Digital Marketing')

plt.legend(loc='upper right') #eita na lekhle label show korbena

# %% [markdown]
# # Adding some visualization

# %%
plt.xlabel('Years')
plt.ylabel('Count of enrollment')
plt.title('Student Enrollment over 8 Years')
plt.plot(df['Year'],df['Programming'],label='Programming',color='red',linewidth=3,linestyle='dashdot',marker='o')
plt.plot(df['Year'],df['Digital Marketing'],label='Digital Marketing',color='black',linewidth=3,linestyle='dotted',marker='o')

plt.legend(loc='upper right') #eita na lekhle label show korbena

# %%
plt.xlabel('Years')
plt.ylabel('Count of enrollment')
plt.title('Student Enrollment over 8 Years')
plt.plot(df['Year'],df['Programming'],label='Programming',color='red',linewidth=3,marker='o')
plt.plot(df['Year'],df['Digital Marketing'],label='Digital Marketing',color='black',linewidth=3,marker='o')
plt.grid()
plt.legend(loc='upper right') #eita na lekhle label show korbena

# %% [markdown]
# # Scatter Plot

# %%
students = pd.read_csv('student_IQdata.csv')
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 2
#       1 students = pd.read_csv('student_IQdata.csv')
# ----> 2 s
#
# NameError: name 's' is not defined

# %%
#Relation between study hours and IQ Score -> Positive Correlation
plt.title('Relation between study hours and IQ Score')
plt.xlabel('Study Hours')
plt.ylabel('IQ Score')
plt.scatter(students['Study_Hour'],students['IQ_Score'])

# %%
#Relation between shoe size hours and IQ -> No Correlation
plt.title('Relation between Shoe size and IQ Score')
plt.xlabel('Shoe Size')
plt.ylabel('IQ Score')
plt.scatter(students['Shoe_Size'],students['IQ_Score'])

# %%
#Relation between Chilling Time and IQ Score -> Negative Correlation
plt.title('Relation between study hours and IQ Score')
plt.xlabel('Chilling Time')
plt.ylabel('IQ Score')
plt.scatter(students['Chilling_Hours'],students['IQ_Score'],marker='o',color='red')

# %% [markdown]
# # Histogram - data distributed over a factor / frequescy

# %% [markdown]
# # left skewed distribution
# # right skewed distribution
# # Symmetrical distribution (Bell Curve)

# %%
plt.xlabel('IQ Score')
plt.ylabel('Frequency of students')
plt.hist(students['IQ_Score'],color='red',edgecolor='black')
# Out:
# (array([11.,  4.,  7.,  7.,  3.,  4.,  1.,  0.,  0.,  1.]),
#  array([ 70. ,  77.5,  85. ,  92.5, 100. , 107.5, 115. , 122.5, 130. ,
#         137.5, 145. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel('Study Hours')
plt.ylabel('Frequency of students')
plt.hist(students['Study_Hour'],bins=15,color='red',edgecolor='black')
plt.show()

# %%
plt.xlabel('Study Hours')
plt.ylabel('Frequency of students')
plt.hist(students['Study_Hour'],bins=[1,2,3,4,5,6,7,8],color='red',edgecolor='black')
# Out:
# (array([2., 5., 3., 3., 3., 2., 2.]),
#  array([1., 2., 3., 4., 5., 6., 7., 8.]),
#  <BarContainer object of 7 artists>)

# %% [markdown]
# # bar chart- categorical values

# %%
data = {
    'Student': [ 'B', 'C', 'D', 'E', 'F', 'G', 'H'],
    'Gender': [ 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male'],
    'StudyHours': [ 2, 5, 3, 7, 4, 8, 1],
    'Attendance': [ 60, 88, 70, 95, 80, 98, 55],
    'Grade': [ 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail']
}

df = pd.DataFrame(data)
df
# Out:
#   Student  Gender  StudyHours  Attendance Grade
# 0       B    Male           2          60  Fail
# 1       C  Female           5          88  Pass
# 2       D    Male           3          70  Fail
# 3       E  Female           7          95  Pass
# 4       F    Male           4          80  Pass
# 5       G  Female           8          98  Pass
# 6       H    Male           1          55  Fail

# %%
#gender wise 

gender_group=df.groupby('Gender').size()
gender_group
gender_group.index
gender_group.values
# Out:
# array([3, 4])

# %%
plt.bar(gender_group.index,gender_group.values,color=['pink','lightblue'],edgecolor='black')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Bar chart of gender among Students')
# Out:
# Text(0.5, 1.0, 'Bar chart of gender among Students')

# %%
#bar chart on real data
df = pd.read_csv('student_data.csv')

# %%
status = df.groupby('CompletionStatus').size()
plt.bar(status.index,status.values,color=['green','blue','red'],edgecolor='black')
plt.xlabel('Completion status')
plt.ylabel('Student count')
plt.title('Status Result of Students')
plt.show()

# %%
#location 
status = df.groupby('Location').size()
plt.bar(status.index,status.values,edgecolor='black')
plt.xlabel('Location')
plt.ylabel('Student count')
plt.title('Bar chart of location of students')
plt.show()

# %% [markdown]
# # pie chart - graphical representation

# %%
status = df.groupby('CompletionStatus').size()
plt.pie(status,labels=status.index,autopct='%1.1f%%',explode=(0.1,0,0), shadow=True)
plt.show()

# %% [markdown]
# https://docs.google.com/document/d/1KmgZ94pjdBlcVc4lUvUTUKlHpkIfTjg7_gJYa35aIbo/edit?tab=t.0

# %%
df = pd.read_csv('Practice.csv') 
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80

# %%
df['Discounted_Price']= df['Price'] * 0.90
df.to_csv("discounted_products.csv",index = False)

# %%
df['EmployeeID'].unique()
df.drop_duplicates(subset=['EmployeeID'])
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1            1350.0
# 2             990.0
# 4            2250.0
# 5            1170.0
# 6            1980.0
# 7            1710.0
# 8            1620.0
# 9            1260.0

# %%
df['Age'].isnull()
df['Salary'].isnull()

df['Age']
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# Name: Salary, dtype: bool

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df = df.dropna(subset=['Salary'])
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Discounted_Price
# 0             1080.0
# 1             1350.0
# 2              990.0
# 3             1080.0
# 4             2250.0
# 5             1170.0
# 6             1980.0
# 9             1260.0
# 10            1350.0

# %%
plt.hist(df['Age'],color=['red'],edgecolor=['black'])
# Out:
# (array([1., 3., 0., 4., 0., 0., 0., 0., 0., 1.]),
#  array([22. , 24.3, 26.6, 28.9, 31.2, 33.5, 35.8, 38.1, 40.4, 42.7, 45. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['Age'],df['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(df['Price'],df['Discounted_Price'])
